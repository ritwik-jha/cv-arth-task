# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
jumanji = cv2.imread('jumanji2.jpg')

# %%
skyscraper = cv2.imread('skyscraper.jpg')

# %%
gijoe = cv2.imread('gijoe.jpg')

# %%
jumanji.shape
# Out:
# (1080, 864, 3)

# %%
skyscraper.shape
# Out:
# (540, 960, 3)

# %%
gijoe.shape
# Out:
# (540, 960, 3)

# %%
stack1 = np.vstack([skyscraper, gijoe])

# %%
plt.imshow(stack1)

# %%
stack1.shape
# Out:
# (1080, 960, 3)

# %%
stack2 = np.hstack([jumanji, stack1])

# %%
plt.imshow(stack2)

# %%
cv2.imshow('title', stack2)
cv2.waitKey()
cv2.destroyAllWindows()
