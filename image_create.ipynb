# %%
import cv2

# %%
import numpy as np
import random
import matplotlib.pyplot as plt

# %%
a = []
for i in range(100):
    b = []
    for j in range(100):
        b.append(random.randint(0, 255))
    a.append(b)

# %%
a = np.array(a)

# %%
plt.imshow(a, cmap='gray')
